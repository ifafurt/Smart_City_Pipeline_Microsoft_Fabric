# %%
# --- GLOBAL PATHS ---
ROOT_PATH = 'abfss://smart_city@onelake.dfs.fabric.microsoft.com/smart_city_lakehouse.Lakehouse/Files'
BASE_PATH = ROOT_PATH

PATH_BRONZE = f"{ROOT_PATH}/bronze/smart_city"
PATH_SILVER = f"{ROOT_PATH}/silver/smart_city"
PATH_GOLD = f"{ROOT_PATH}/gold/smart_city"

# --- GLOBAL CONSTANTS ---
TIMEZONE = "UTC"
TIMESTAMP_FORMAT = "yyyy-MM-dd HH:mm:ss"

PRIM_COL_NAME = "_id"
SOURCE_COL_NAME = "_source"
IMPORTDATE_COL_NAME = "_datetime_import"

print("nb_config Loaded")
# Out:
# StatementMeta(, 1f907108-238c-44e5-834d-4eb77f2fc6c1, 3, Finished, Available, Finished)
# nb_config Loaded
